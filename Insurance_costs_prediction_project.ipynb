# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
data= pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Medical%20Cost%20Insurance/medical_cost_insurance.csv")

data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.515695  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
Observations:
    
1.The data set contains 1338 rows and 7 columns ,out of which "Charges " is the target variable and remainings are independant variable.
2.There is no null values in the data set
3.The data set contains 3 columns of object data type , 2 columns contains float data type and 2 coulmns contain int datatype

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
data['charges'].nunique()
# Out:
# 1337

# %%
for i in data.columns:
    print(data[i].value_counts())
    
    print('\n..............')
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64
#
# ..............
# sex
# male      676
# female    662
# Name: count, dtype: int64
#
# ..............
# bmi
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: count, Length: 548, dtype: int64
#
# ..............
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64
#
# ...

# %%
sns.lmplot(x='age',y='charges',data=data,palette ='colorblind')

# %%
sns.lmplot(x='bmi',y='charges',data=data,palette ='colorblind')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc = LabelEncoder()

# %%
df1=lab_enc.fit_transform(data['smoker'])
pd.Series(df1)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Length: 1338, dtype: int32

# %%
data['smoker']=df1

data
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       0  northwest  10600.54830
# 1334   18  female  31.920         0       0  northeast   2205.98080
# 1335   18  female  36.850         0       0  southeast   1629.83350
# 1336   21  female  25.800         0       0  southwest   2007.94500
# 1337   61  female  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df2=lab_enc.fit_transform(data['sex'])
pd.Series(df2)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Length: 1338, dtype: int32

# %%
data['sex']=df2

data
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    0  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    0  31.920         0       0  northeast   2205.98080
# 1335   18    0  36.850         0       0  southeast   1629.83350
# 1336   21    0  25.800         0       0  southwest   2007.94500
# 1337   61    0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df3=lab_enc.fit_transform(data['region'])
pd.Series(df3)
# Out:
# 0       3
# 1       2
# 2       2
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    2
# 1336    3
# 1337    1
# Length: 1338, dtype: int32

# %%
data['region']=df3

data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.dtypes
# Out:
# age           int64
# sex           int32
# bmi         float64
# children      int64
# smoker        int32
# region        int32
# charges     float64
# dtype: object

# %%
plt.figure(figsize=(20,25),facecolor='green')
plotnumber =1
for column in data:
    if plotnumber<=7:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(data[column],color='b')
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.show()

# %%
plt.figure(figsize=(20,25))
plotnumber =1
for i in data:
    if plotnumber<=7:
        plt.subplot(6,4,plotnumber)
        sns.boxplot(data[i],palette='Set2_r')
        plt.xlabel(i)
        
    plotnumber+=1
    
plt.show()

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=data.drop(columns =['charges'])
y=data['charges']

# %%
plt.figure(figsize=(15,20))
plotnumber = 1

for column in x:
    if plotnumber <=9:
        ax= plt.subplot(3,3,plotnumber)
        sns.stripplot(x=y,y=x[column],hue=y)
    plotnumber +=1
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-1.43876426, -1.0105187 , -0.45332   , -0.90861367,  1.97058663,
#          1.34390459],
#        [-1.50996545,  0.98959079,  0.5096211 , -0.07876719, -0.5074631 ,
#          0.43849455],
#        [-0.79795355,  0.98959079,  0.38330685,  1.58092576, -0.5074631 ,
#          0.43849455],
#        ...,
#        [-1.50996545, -1.0105187 ,  1.0148781 , -0.90861367, -0.5074631 ,
#          0.43849455],
#        [-1.29636188, -1.0105187 , -0.79781341, -0.90861367, -0.5074631 ,
#          1.34390459],
#        [ 1.55168573, -1.0105187 , -0.26138796, -0.90861367,  1.97058663,
#         -0.46691549]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=200)
y_train.head()
# Out:
# 1233    11345.51900
# 675      7222.78625
# 701      9541.69555
# 954     20009.63365
# 677     46130.52650
# Name: charges, dtype: float64

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
data.tail(2)
# Out:
#       age  sex    bmi  children  smoker  region     charges
# 1336   21    0  25.80         0       0       3   2007.9450
# 1337   61    0  29.07         0       1       1  29141.3603

# %%
print('data  :',regression.predict(scaler.transform([[21,0,25.80,0,0,3]])))
# Out:
# data  : [881.55165667]

# %%
regression.score(x_train,y_train)
# Out:
# 0.7467583947511185

# %%
regression.score(x_test,y_test)
# Out:
# 0.7605945243767418

# %%
x_test[1]
# Out:
# array([-0.01474046, -1.0105187 , -1.05618347,  3.24061871, -0.5074631 ,
#        -0.46691549])

# %%
y_pred= regression.predict(x_test)

# %%
y_pred
# Out:
# array([11438.33632378,  8630.3408796 ,  7618.61813582,  8594.95216142,
#         1785.32705082,  4948.9115503 , 40376.55614718,  4294.59611566,
#        33619.7049322 ,  8665.6020341 , 34717.23618637, 10411.15798143,
#         9060.74222628,  6471.95772379, 14074.19573567,  5820.27489986,
#        15412.39470256, 28038.10546328, 11628.52400701, 10377.93235009,
#        10834.86182328,  2702.90654114, 11816.24653967, 35168.41124457,
#         5682.44232878,  -258.45577296, 25209.39826508, 10195.57344406,
#         8432.73631255, 40375.78354113, 19048.97267514, 12108.2429814 ,
#         4899.56263646,  3030.24488261,  4623.65803573,  8981.44762885,
#        12773.70808879,  -698.06078289, 13258.77012178,  2066.91759347,
#        30162.90351841, 38726.85242845, 28400.99697968, 12451.98211768,
#        11524.21865644, 11707.85007884, 16116.84390208, 12716.25068373,
#         -217.4593728 , 14226.80916887, 33051.04719625, 13153.6319527 ,
# ...

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual charges')
plt.ylabel('predicted charges')
plt.title('Actual vs predicted charges')
plt.show()

# %%
from sklearn.metrics import mean_squared_error ,mean_absolute_error

# %%
y_pred = regression.predict(x_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 4205.1284563960435

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 35437527.50607039

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 5952.942760187636
